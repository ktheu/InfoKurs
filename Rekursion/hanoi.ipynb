# %%
def hanoi(n, start, ziel, zwischen):
    global aufruf
    aufruf+=1
    dieser_aufruf = aufruf
    
    #print(f'{aufruf}:  {n} {start} {ziel} {zwischen}')
    '''
    n: Anzahl der Scheiben
    start, ziel, zwischen: Strings, die 3 Stapel bezeichnen
    '''
    if n == 0:
        print(f'Ende {dieser_aufruf}')
        return
    hanoi(n-1,start,zwischen,ziel)
    #print("Scheibe",n,"von",start,"nach",ziel)
    hanoi(n-1,zwischen,ziel,start)
    print(f'Ende {dieser_aufruf}')

# %%
aufruf = 0
hanoi(3,'A','C','B')
# Out:
# Ende 4
# Ende 5
# Ende 3
# Ende 7
# Ende 8
# Ende 6
# Ende 2
# Ende 11
# Ende 12
# Ende 10
# Ende 14
# Ende 15
# Ende 13
# Ende 9
# Ende 1

# %%
Die folgende Funktion printed die Verlegeoperationen bei den Türmen von Hanoi.
Ist es korrekt zu sagen, dass die Startreihenfolge der rekursiven Funktion eine preorder-Reihenfolge ist und
die Endereihenfolge eine inorder-Reihenfolge ist?



def hanoi(n, start, ziel, zwischen):
    if n == 0: return
    hanoi(n-1,start,zwischen,ziel)
    print("Scheibe",n,"von",start,"nach",ziel)
    hanoi(n-1,zwischen,ziel,start)
