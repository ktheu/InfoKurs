# %%
def prepare(s):
    '''
    s: Klartext
    returns: String, Klartext ohne Umlaute, Satzzeichen, Leerzeichen, nur Großbuchstaben
    '''
    s = s.upper()
    s = s.replace('Ö','OE').replace('Ü','UE').replace('Ä','AE').replace('ß','SS')
    return ''.join([c for c in list(s) if c.isalpha()])

# %% [markdown]
# Anfang von "Jane Eyre - Charlotte Bronte"

# %% [raw]
# ...

# %% [markdown]
# key = 'GENTLEMAN'

# %% [raw]
# ...

# %% [markdown]
# Für den Chiffretext wurden zwei Schlüssel probiert:
#
# key1: GRNAWOPST
# key2: PRANWORST
#
# Welcher der beiden nicht korrekten keys ist der bessere?
#
# Entschlüsselung mit key1:

# %% [raw]
# key = GRNAWOPST
# ...

# %%
0,0423100490196078

# %% [raw]
# key = PRANWORST
# ...

# %% [raw]
# Question:
# I decipher a german vigenere-chiffretext with two keys A and B (both are not the correct keys).
# Key A yields text with coincidenzindex 0.04231, key B yields 0.04142. So key A is 'better'
# since its coincidenzindex is nearer to the average german coincidenzindex 0.076.
# If I do this with the N-gram cost-functions I get -3,647 for key A and -3,875 for key B.
# What is the value they should be close to, if they are 'good guesses'?

# %% [raw]
# Kostenfunktionen:
# GRNAWOPST - 0.0423100490196078 - -3,64769707247615 - 4,56954336166382
# PRANWORST - 0.041421568627451 - -3,87529975175858  - 4,56543302536011
# GENTLEMAN - 0,086734068627451               -2,95411778613925
